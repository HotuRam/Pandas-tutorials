# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
data = pd.read_csv('../data/data_fs.csv',index_col=0)
data.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose
# 0         6             radio/TV
# 1        48             radio/TV
# 2        12            education
# 3        42  furniture/equipment
# 4        24                  car

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 78.1+ KB

# %%
data.describe()
# Out:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
data.iloc[205:215,:]
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 205   38    male    3    free          little           little          10623
# 206   43    male    2     own          little              NaN           1935
# 207   26    male    2     own          little         moderate           1424
# 208   21    male    1     own          little           little           6568
# 209   55    male    2     own            rich              NaN           1413
# 210   33    male    2     own             NaN              NaN           3074
# 211   45  female    1     own             NaN              NaN           3835
# 212   50    male    2     own          little           little           5293
# 213   66    male    3     own          little             rich           1908
# 214   51    male    2     own             NaN              NaN           3342
#
#      Duration              Purpose
# 205        30                  car
# 206        12  furniture/equipment
# ...

# %%
np.unique(data['Sex'].values,return_counts=True)
# Out:
# (array(['female', 'male'], dtype=object), array([310, 690], dtype=int64))

# %%
np.unique(data['Purpose'].values,return_counts=True)
# Out:
# (array(['business', 'car', 'domestic appliances', 'education',
#         'furniture/equipment', 'radio/TV', 'repairs', 'vacation/others'],
#        dtype=object),
#  array([ 97, 337,  12,  59, 181, 280,  22,  12], dtype=int64))

# %%
sns.distplot(data['Duration'])
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Density'>
